# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello ", end = '')
print("World", end ='')
print("Good bye", end ='')
# Out:
# Hello WorldGood bye

# %%
string = eval(input("Enter your name = "))
print(string)
# Out:
# Enter your name =  prethul
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 string = eval(input("Enter your name = "))
#       2 print(string)
#
# File <string>:1
#
# NameError: name 'prethul' is not defined

# %%
x = 20.564633
x = format(x,".3f")
x
# Out:
# '20.565'

# %%
x = 20.564633 
x = format(x,".4f")
x
# Out:
# '20.5646'

# %%
x = 20.564633
x = format(x,"7.3f")
x
print(type(x))
# Out:
# <class 'str'>

# %%
x = 20.564633
x = eval(format(x,"7.3f"))
x
print(type(x))

# %% [markdown]
# Python inbuild function

# %%
import math

# %%
print(math.ceil(10.34)) #celi function ta 10 doshomik ar purno man nise .
# Out:
# 11

# %%
print(math.floor(4.9)) #floor X–এর নিচের দিকের নিকটতম পূর্ণসংখ্যা নেয়।
# Out:
# 4

# %%
print(math.exp(10.23))
# Out:
# 27722.51006805505

# %%
print(math.log(10.45))
# Out:
# 2.34660197841082

# %%
print(math.log(10,10)) #log ar man print kora hoice
# Out:
# 1.0

# %%
print(math.sqrt(16)) #sqrt function dara borgomul ber kora hoice
# Out:
# 4.0

# %%
ord ("A")
# Out:
# 65

# %%
round(1.5) #1.5 ar kacer songka ke print korbe
# Out:
# 2

# %% [markdown]
# Exercise question

# %%
abs (-2)
# Out:
# 2

# %%
min(102,120,110)
# Out:
# 102

# %%
max(45,78,9,90)
# Out:
# 90

# %%
ord("A")
# Out:
# 65

# %%
ord("f")
# Out:
# 102

# %%
num1 = 10
num2 = 20.65
sum =  num1 + num2 
print(sum)
# Out:
# 30.65

# %%
#Write a program to print ‘F’ to ‘A’ in five different lines.

print("F")
print("E")
print("D")
print("C")
print("B")
print("A")
# Out:
# F
# E
# D
# C
# B
# A

# %%
"""2. Write a program to read and store the name of three different cities in three d
variables and print all the contents of variables on the console."""

City1 = input("Enter your city = ")
city2 = input("Enter your city =")
city3 = input("Enter yor city =")
# Out:
# Enter your city =  dhaka
# Enter your city = barishal
# Enter yor city = prerojpur

# %%
"""Write a program to prompt the user to enter and display their personal details, su
name, address and mobile number."""

name = input("Enter your name =")
address = input("Enter your address =")
mobile_number = input("Enter your mobile_number")

print("your name" , name)
print("your current address", address)
print("Your mobile number", mobile_number)
# Out:
# Enter your name = prethul
# Enter your address = Gazipur
# Enter your mobile_number 01873324664
# your name prethul
# your current address Gazipur
# Your mobile number 01873324664
